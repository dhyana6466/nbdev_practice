# %% [raw]
# ---
# description: Learning nbdev for research projects
# output-file: index.html
# title: nbdev_practice
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Install

# %% [markdown]
# ```bash
# pip install nbdev_practice
# ```

# %% [markdown]
# ## How to use

# %%
from nbdev_practice.core import say_hello

# %%
say_hello("Dhyana")
# Out:
# 'Hello, Dhyana!'
