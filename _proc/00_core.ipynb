# %% [raw]
# ---
# description: My first nbdev notebook
# output-file: core.html
# title: Core Module
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(say_hello)
# Out:
# def say_hello(
#     name
# ):
# """Greet someone by name"""

# %%
say_hello("Dhyana")
# Out:
# 'Hello, Dhyana!'
