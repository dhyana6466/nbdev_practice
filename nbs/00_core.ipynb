# %%
#| default_exp core

# %% [markdown]
# # Core Module
#
# > My first nbdev notebook

# %%
#| export
def say_hello(name):
    """Greet someone by name"""
    return f"Hello, {name}!"

# %%
say_hello("Dhyana")
# Out:
# 'Hello, Dhyana!'
