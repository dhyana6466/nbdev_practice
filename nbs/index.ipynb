# %% [markdown]
# # nbdev_practice
#
# > Learning nbdev for research projects

# %% [markdown]
# ## Install

# %% [markdown]
# ```bash
# pip install nbdev_practice
# ```

# %% [markdown]
# ## How to use

# %%
from nbdev_practice.core import say_hello

# %%
say_hello("Dhyana")
# Out:
# 'Hello, Dhyana!'
